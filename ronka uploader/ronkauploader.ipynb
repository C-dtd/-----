# %%
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import os
import time

print(
    """
    A RONKA'S GREAT SERPENT IS APPEAR!!!
⠀⠀⠀⠀⠀⠀⠀⢀⡠⠖⠊⠉⠉⠉⠓⠲⠤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⡰⠋⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠈⢣⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢰⠃⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢳⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣾⡶⣠⠏⣦⠀⢀⣄⠀⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⡇⠀⢣⣄⣠⠇⠈⠉⠀⠀⠀⠀⠀⠀⣰⣿⢦⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣇⠀⠀⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⡰⠃⢸⠘ ⡷⡄⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⡿⡀⠀⠀⠀⠀⠀⠀⠀⣀⡠⠔⠋⠀⠀⡸⠀⡇ ⢹⡄⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⡇⠈⠑⠒⠒⠒⠒⠋⠉⠀⠀⠀⠀⠀⢠⠃⠀⡇ ⢸⢳⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡰⠃⠀⡸⠀⢸   ⢸⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠸⣆⠀⠀⠀⠀⠀⠀⠀⢀⡠⠔⠊⠀⢀⠜⠁⠀⡏  ⡜⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠹⡓⠤⠤⠤⠤⠒⠊⠉⠀⠀⢀⡴⠋⠀⢀⡜ ⡰⠁⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠙⢤⣀⣀⣀⣀⣀⣀⠤⠒⠉⠀⢀⣠ ⠾⠊⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⠻⠭⠤⠤⠤⠤⠤⠴⠖⠋⠁⠀⠀⠀⠀⠀⠀⠀
    """
)

race = {
    '남가딘':1, '남고휴':2, '남라펠':3, '남레젠':4, '남우라':5, '남중휴':6, '남코테':7, '남로스갈':8,
    '여가딘':9, '여고휴':10, '여라펠':11, '여비에라':12, '여레젠':13, '여우라':14, '여중휴':15, '여코테':16,
    '남비에라':17, '여로스갈': 18
}

try:
    driver = wb.Chrome()
    driver.set_window_position(0, 0)
    driver.set_window_size(1920, 1080)
    driver.get('https://ronkacloset.com/admin')
    driver.implicitly_wait(60)

    id_input = driver.find_element(By.CSS_SELECTOR, 'div.input_form>input[type=text]')
    pw_input = driver.find_element(By.CSS_SELECTOR, 'div.input_form>input[type=password]')
    login_btn = driver.find_element(By.CSS_SELECTOR, '#cocoaModal > div > div > article > form > p > button')
    id_input.send_keys('upload_savior')
    pw_input.send_keys('Sa54910gr-')
    login_btn.send_keys(Keys.ENTER)
    time.sleep(5)

    item_list = os.listdir('./ronka')
    path = os.getcwd().replace('\\', '/')
    success_list = []
    fail_list = []

    for i in item_list:
        driver.get('https://ronkacloset.com/admin/shopping/product')
        driver.implicitly_wait(10)
        img_list = os.listdir(f'./ronka/{i}')

        search = driver.find_element(By.CSS_SELECTOR, '#keyword_search_input')
        search.send_keys(i)
        search.send_keys(Keys.ENTER)
        driver.implicitly_wait(10)
        search_list = driver.find_elements(By.CSS_SELECTOR, 'div.item-tit.inline-blocked > a:nth-child(1)')

        if len(search_list) != 1:
            fail_list.append(f'{i}: 전체')
            break
        search_list[0].click()
        driver.implicitly_wait(10)
        
        table = driver.find_elements(By.CSS_SELECTOR, 'table.noBorder')[1]
        tds = table.find_elements(By.CSS_SELECTOR, 'td')
        for td in tds:
            if td.text == '':
                continue
            idx = race.get(td.text)
            name = td.text
            if idx == None:
                fail_list.append(f'{i}: {name}')
                continue
            img_input = driver.find_elements(By.CSS_SELECTOR, 'input[type=file]')[3]
            if not os.path.isfile(f'{path}/ronka/{i}/{idx}.jpg'):
                continue
            td.clear()
            td.click()
            img_input.send_keys(f'{path}/ronka/{i}/{idx}.jpg')
            if f'{idx}.jpg' in img_list:
                img_list.remove(f'{idx}.jpg')

            success_list.append(f'{i}: {name}')
            time.sleep(1.5)
            td.send_keys(Keys.ENTER)
            td.send_keys(name)

        driver.find_element(By.CSS_SELECTOR, '#header > div > div.headerbar-right > ul > li:nth-child(2) > a').click()
        fail_list += [f'{i}: {img}' for img in img_list]
        time.sleep(5)
    driver.quit()

except Exception as e:
    print(e.Message)
    # with open(f"./error log {time.strftime('%Y%m%d %H%M%S')}.txt", 'w') as f:
    #     f.write(e+'\n')

finally:
    with open(f"./log {time.strftime('%Y%m%d %H%M%S')}.txt", 'w') as f:
        f.write(time.strftime('%Y/%m/%d %H:%M:%S')+'\n')
        f.write('////SUCCESS LIST'+'\n')
        for i in success_list:
            f.write(i+'\n')
        f.write('////FAIL LIST'+'\n')
        for i in fail_list:
            f.write(i+'\n')
# Out:
#     A RONKA'S GREAT SERPENT IS APPEAR!!!
# ⠀⠀⠀⠀⠀⠀⠀⢀⡠⠖⠊⠉⠉⠉⠓⠲⠤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⡰⠋⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠈⢣⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⢰⠃⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢳⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⣾⡶⣠⠏⣦⠀⢀⣄⠀⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⡇⠀⢣⣄⣠⠇⠈⠉⠀⠀⠀⠀⠀⠀⣰⣿⢦⡀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⣇⠀⠀⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⡰⠃⢸⠘ ⡷⡄⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⡿⡀⠀⠀⠀⠀⠀⠀⠀⣀⡠⠔⠋⠀⠀⡸⠀⡇ ⢹⡄⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⡇⠈⠑⠒⠒⠒⠒⠋⠉⠀⠀⠀⠀⠀⢠⠃⠀⡇ ⢸⢳⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⢧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡰⠃⠀⡸⠀⢸   ⢸⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠸⣆⠀⠀⠀⠀⠀⠀⠀⢀⡠⠔⠊⠀⢀⠜⠁⠀⡏  ⡜⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠹⡓⠤⠤⠤⠤⠒⠊⠉⠀⠀⢀⡴⠋⠀⢀⡜ ⡰⠁⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠙⢤⣀⣀⣀⣀⣀⣀⠤⠒⠉⠀⢀⣠ ⠾⠊⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⠻⠭⠤⠤⠤⠤⠤⠴⠖⠋⠁⠀⠀⠀⠀⠀⠀⠀
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 40
#      38 driver.implicitly_wait(60)
# ---> 40 id_input = driver.find_element(By.CSS_SELECTOR, 'div.input_form>input[type=text]')
#      41 pw_input = driver.find_element(By.CSS_SELECTOR, 'div.input_form>input[type=password]')
#
# File c:\Users\SMHRD\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\SMHRD\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\SMHRD\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.input_form>input[type=text]"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF60A6BEEB2+31554]
# 	(No symbol) [0x00007FF60A637EE9]
# 	(No symbol) [0x00007FF60A4F872A]
# 	(No symbol) [0x00007FF60A548434]
# 	(No symbol) [0x00007FF60A54853C]
# 	(No symbol) [0x00007FF60A58F6A7]
# 	(No symbol) [0x00007FF60A56D06F]
# 	(No symbol) [0x00007FF60A58C977]
# 	(No symbol) [0x00007FF60A56CDD3]
# 	(No symbol) [0x00007FF60A53A33B]
# 	(No symbol) [0x00007FF60A53AED1]
# 	GetHandleVerifier [0x00007FF60A9C8B2D+3217341]
# 	GetHandleVerifier [0x00007FF60AA15AF3+3532675]
# 	GetHandleVerifier [0x00007FF60AA0B0F0+3489152]
# 	GetHandleVerifier [0x00007FF60A76E786+750614]
# 	(No symbol) [0x00007FF60A64376F]
# 	(No symbol) [0x00007FF60A63EB24]
# 	(No symbol) [0x00007FF60A63ECB2]
# 	(No symbol) [0x00007FF60A62E17F]
# 	BaseThreadInitThunk [0x00007FF9D3687374+20]
# 	RtlUserThreadStart [0x00007FF9D38FCC91+33]
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 100
#      97     driver.quit()
#      99 except Exception as e:
# --> 100     print(e.Message)
#     101     # with open(f"./error log {time.strftime('%Y%m%d %H%M%S')}.txt", 'w') as f:
#     102     #     f.write(e+'\n')
#     103
#     104 finally:
#     105     with open(f"./log {time.strftime('%Y%m%d %H%M%S')}.txt", 'w') as f:
#
# AttributeError: 'NoSuchElementException' object has no attribute 'Message'

# %%
# !pyinstaller --onefile ronka_uploader.py
# Out:
# 2396 INFO: PyInstaller: 6.9.0, contrib hooks: 2024.7
# 2396 INFO: Python: 3.11.7 (conda)
# 2404 INFO: Platform: Windows-10-10.0.19045-SP0
# 2404 INFO: Python environment: c:\Users\SMHRD\anaconda3
# 2404 INFO: wrote c:\Users\SMHRD\Desktop\개인 공부\ronka uploader\ronka_uploader.spec
# 2408 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\SMHRD\\anaconda3\\Scripts\\pyinstaller.exe',
#  'c:\\Users\\SMHRD\\anaconda3\\python311.zip',
#  'c:\\Users\\SMHRD\\anaconda3\\DLLs',
#  'c:\\Users\\SMHRD\\anaconda3\\Lib',
#  'c:\\Users\\SMHRD\\anaconda3',
#  'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages',
#  'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\win32',
#  'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\Pythonwin',
#  'c:\\Users\\SMHRD\\Desktop\\개인 공부\\ronka uploader']
# 2866 INFO: checking Analysis
# 2870 INFO: Building because C:\Users\SMHRD\Desktop\개인 공부\ronka uploader\ronka_uploader.py changed
# 2870 INFO: Running Analysis Analysis-00.toc
# 2870 INFO: Target bytecode optimization level: 0
# 2870 INFO: Initializing module dependency graph...
# 2870 INFO: Caching module graph hooks...
# 2884 INFO: Analyzing base_library.zip ...
# 10388 INFO: Loading module hook 'hook-heapq.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 10466 INFO: Loading module hook 'hook-encodings.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 14092 INFO: Loading module hook 'hook-pickle.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 15499 INFO: Caching module dependency graph...
# 15633 INFO: Looking for Python shared library...
# 15633 INFO: Using Python shared library: c:\Users\SMHRD\anaconda3\python311.dll
# 15633 INFO: Analyzing c:\Users\SMHRD\Desktop\개인 공부\ronka uploader\ronka_uploader.py
# 15644 INFO: Loading module hook 'hook-selenium.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 15945 INFO: Loading module hook 'hook-platform.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 16228 INFO: Loading module hook 'hook-certifi.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 17148 INFO: Loading module hook 'hook-xml.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 17148 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 17354 INFO: Processing module hooks...
# 17361 INFO: Performing binary vs. data reclassification (17 entries)
# 17375 INFO: Looking for ctypes DLLs
# 17388 INFO: Analyzing run-time hooks ...
# 17388 INFO: Including run-time hook 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 17388 INFO: Including run-time hook 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 17388 INFO: Processing pre-find module path hook _pyi_rth_utils from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 17395 INFO: Loading module hook 'hook-_pyi_rth_utils.py' from 'c:\\Users\\SMHRD\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 17398 INFO: Looking for dynamic libraries
# 17648 INFO: Extra DLL search directories (AddDllDirectory): []
# 17648 INFO: Extra DLL search directories (PATH): []
# 18109 INFO: Warnings written to c:\Users\SMHRD\Desktop\개인 공부\ronka uploader\build\ronka_uploader\warn-ronka_uploader.txt
# 18131 INFO: Graph cross-reference written to c:\Users\SMHRD\Desktop\개인 공부\ronka uploader\build\ronka_uploader\xref-ronka_uploader.html
# 18150 INFO: checking PYZ
# 18168 INFO: checking PKG
# 18169 INFO: Building because toc changed
# 18169 INFO: Building PKG (CArchive) ronka_uploader.pkg
# 22217 INFO: Building PKG (CArchive) ronka_uploader.pkg completed successfully.
# 22226 INFO: Bootloader c:\Users\SMHRD\anaconda3\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 22226 INFO: checking EXE
# 22226 INFO: Building because toc changed
# 22226 INFO: Building EXE from EXE-00.toc
# 22226 INFO: Copying bootloader EXE to c:\Users\SMHRD\Desktop\개인 공부\ronka uploader\dist\ronka_uploader.exe
# 22267 INFO: Copying icon to EXE
# 22299 INFO: Copying 0 resources to EXE
# 22299 INFO: Embedding manifest in EXE
# 22330 INFO: Appending PKG archive to EXE
# 22340 INFO: Fixing EXE headers
# 22647 INFO: Building EXE from EXE-00.toc completed successfully.
